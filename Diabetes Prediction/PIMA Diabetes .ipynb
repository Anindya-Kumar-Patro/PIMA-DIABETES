# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
from matplotlib import pyplot as plt

# %%
data = pd.read_csv('diabetes.csv')

# %%
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
# Pregnancies                 768 non-null int64
# Glucose                     768 non-null int64
# BloodPressure               768 non-null int64
# SkinThickness               768 non-null int64
# Insulin                     768 non-null int64
# BMI                         768 non-null float64
# DiabetesPedigreeFunction    768 non-null float64
# Age                         768 non-null int64
# Outcome                     768 non-null int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
data.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
ax = sns.lineplot(x="Pregnancies",y="Outcome", data=data)

# %%
sns.set(style="whitegrid")
ax = sns.barplot(x="Outcome", y ="Pregnancies", data=data)

# %%
data.shape
# Out:
# (768, 9)

# %%
pd.qcut(data['Pregnancies'],3)
# Out:
# 0        (5.0, 17.0]
# 1      (-0.001, 2.0]
# 2        (5.0, 17.0]
# 3      (-0.001, 2.0]
# 4      (-0.001, 2.0]
#            ...
# 763      (5.0, 17.0]
# 764    (-0.001, 2.0]
# 765       (2.0, 5.0]
# 766    (-0.001, 2.0]
# 767    (-0.001, 2.0]
# Name: Pregnancies, Length: 768, dtype: category
# Categories (3, interval[float64]): [(-0.001, 2.0] < (2.0, 5.0] < (5.0, 17.0]]

# %%
dataf = [data]

for dataset in dataf:
   
    dataset.loc[(dataset['Pregnancies'] > 0.0) & (dataset['Pregnancies'] <= 2.0), 'Pregnancies'] = 0
    dataset.loc[(dataset['Pregnancies'] > 2.0) & (dataset['Pregnancies'] <= 5.0), 'Pregnancies']   = 1
    dataset.loc[(dataset['Pregnancies'] > 5.0) & (dataset['Pregnancies'] <= 17.0), 'Pregnancies']   = 2
    
   
    dataset['Pregnancies'] = dataset['Pregnancies'].astype(int)

# %%
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            2      148             72             35        0  33.6
# 1            0       85             66             29        0  26.6
# 2            2      183             64              0        0  23.3
# 3            0       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
ax = sns.lineplot(x="Glucose",y="Outcome", data=data)

# %%
pd.qcut(data['Glucose'],2)
# Out:
# 0       (117.0, 199.0]
# 1      (-0.001, 117.0]
# 2       (117.0, 199.0]
# 3      (-0.001, 117.0]
# 4       (117.0, 199.0]
#             ...
# 763    (-0.001, 117.0]
# 764     (117.0, 199.0]
# 765     (117.0, 199.0]
# 766     (117.0, 199.0]
# 767    (-0.001, 117.0]
# Name: Glucose, Length: 768, dtype: category
# Categories (2, interval[float64]): [(-0.001, 117.0] < (117.0, 199.0]]

# %%
dataf = [data]

for dataset in dataf:
   
    dataset.loc[(dataset['Glucose'] > -0.001) & (dataset['Glucose'] <= 117.0), 'Glucose'] = 0
    dataset.loc[(dataset['Glucose'] >117.0) & (dataset['Glucose'] <= 199.0), 'Glucose']   = 1
    
    
   
    dataset['Glucose'] = dataset['Glucose'].astype(int)

# %%
ax = sns.lineplot(x="BloodPressure",y="Outcome",data=data)

# %%
pd.cut(data['BloodPressure'],4)
# Out:
# 0      (61.0, 91.5]
# 1      (61.0, 91.5]
# 2      (61.0, 91.5]
# 3      (61.0, 91.5]
# 4      (30.5, 61.0]
#            ...
# 763    (61.0, 91.5]
# 764    (61.0, 91.5]
# 765    (61.0, 91.5]
# 766    (30.5, 61.0]
# 767    (61.0, 91.5]
# Name: BloodPressure, Length: 768, dtype: category
# Categories (4, interval[float64]): [(-0.122, 30.5] < (30.5, 61.0] < (61.0, 91.5] < (91.5, 122.0]]

# %%
dataf = [data]

for dataset in dataf:
   
    dataset.loc[(dataset['BloodPressure'] > 0.0) & (dataset['BloodPressure'] <= 30.5), 'BloodPressure'] = 0
    dataset.loc[(dataset['BloodPressure'] > 30.5) & (dataset['BloodPressure'] <= 61.0), 'BloodPressure']   = 1
    dataset.loc[(dataset['BloodPressure'] > 61.0) & (dataset['BloodPressure'] <= 91.5), 'BloodPressure']   = 2
    dataset.loc[(dataset['BloodPressure'] > 91.5) & (dataset['BloodPressure'] <= 122.0), 'BloodPressure']   = 3
    
   
    dataset['BloodPressure'] = dataset['BloodPressure'].astype(int)

# %%
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            2        1              2             35        0  33.6
# 1            0        0              2             29        0  26.6
# 2            2        1              2              0        0  23.3
# 3            0        0              2             23       94  28.1
# 4            0        1              1             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
ax = sns.lineplot(x="SkinThickness",y="Outcome",data=data)

# %%
pd.cut(data['SkinThickness'],5)
# Out:
# 0        (19.8, 39.6]
# 1        (19.8, 39.6]
# 2      (-0.099, 19.8]
# 3        (19.8, 39.6]
# 4        (19.8, 39.6]
#             ...
# 763      (39.6, 59.4]
# 764      (19.8, 39.6]
# 765      (19.8, 39.6]
# 766    (-0.099, 19.8]
# 767      (19.8, 39.6]
# Name: SkinThickness, Length: 768, dtype: category
# Categories (5, interval[float64]): [(-0.099, 19.8] < (19.8, 39.6] < (39.6, 59.4] < (59.4, 79.2] < (79.2, 99.0]]

# %%
dataf = [data]

for dataset in dataf:
   
    dataset.loc[(dataset['SkinThickness'] > 0.0) & (dataset['SkinThickness'] <= 19.8), 'SkinThickness'] = 0
    dataset.loc[(dataset['SkinThickness'] > 19.8) & (dataset['SkinThickness'] <= 39.6), 'SkinThickness']   = 1
    dataset.loc[(dataset['SkinThickness'] > 39.6) & (dataset['SkinThickness'] <= 59.4), 'SkinThickness']   = 2
    dataset.loc[(dataset['SkinThickness'] > 59.4) & (dataset['SkinThickness'] <= 79.2), 'SkinThickness']   = 3
    dataset.loc[(dataset['SkinThickness'] > 79.2) & (dataset['SkinThickness'] <= 99.0), 'SkinThickness']   = 4
    
   
    dataset['SkinThickness'] = dataset['SkinThickness'].astype(int)

# %%
ax = sns.lineplot(x="Insulin",y="Outcome",data=data)

# %%
pd.cut(data['Insulin'],2)
# Out:
# 0      (-0.846, 423.0]
# 1      (-0.846, 423.0]
# 2      (-0.846, 423.0]
# 3      (-0.846, 423.0]
# 4      (-0.846, 423.0]
#             ...
# 763    (-0.846, 423.0]
# 764    (-0.846, 423.0]
# 765    (-0.846, 423.0]
# 766    (-0.846, 423.0]
# 767    (-0.846, 423.0]
# Name: Insulin, Length: 768, dtype: category
# Categories (2, interval[float64]): [(-0.846, 423.0] < (423.0, 846.0]]

# %%
dataf = [data]

for dataset in dataf:
   
    dataset.loc[(dataset['Insulin'] > -0.846) & (dataset['Insulin'] <= 423.0), 'Insulin'] = 0
    dataset.loc[(dataset['Insulin'] >423.0) & (dataset['Insulin'] <= 846.0), 'Insulin']   = 1
    
    
   
    dataset['Insulin'] = dataset['Insulin'].astype(int)

# %%
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            2        1              2              1        0  33.6
# 1            0        0              2              1        0  26.6
# 2            2        1              2              0        0  23.3
# 3            0        0              2              1        0  28.1
# 4            0        1              1              1        0  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
ax=sns.lineplot(x="BMI",y="Outcome",data=data)

# %%
pd.cut(data['BMI'],3)
# Out:
# 0      (22.367, 44.733]
# 1      (22.367, 44.733]
# 2      (22.367, 44.733]
# 3      (22.367, 44.733]
# 4      (22.367, 44.733]
#              ...
# 763    (22.367, 44.733]
# 764    (22.367, 44.733]
# 765    (22.367, 44.733]
# 766    (22.367, 44.733]
# 767    (22.367, 44.733]
# Name: BMI, Length: 768, dtype: category
# Categories (3, interval[float64]): [(-0.0671, 22.367] < (22.367, 44.733] < (44.733, 67.1]]

# %%
dataf = [data]

for dataset in dataf:
   
    dataset.loc[(dataset['BMI'] > -0.0671) & (dataset['BMI'] <= 22.367), 'BMI'] = 0
    dataset.loc[(dataset['BMI'] > 22.367) & (dataset['BMI'] <= 44.733), 'BMI']   = 1
    dataset.loc[(dataset['BMI'] > 44.733) & (dataset['BMI'] <= 67.1), 'BMI']   = 2
    
   
    dataset['BMI'] = dataset['BMI'].astype(int)

# %%
ax = sns.lineplot(x="DiabetesPedigreeFunction",y="Outcome",data=data)

# %%
pd.cut(data['DiabetesPedigreeFunction'],2)
# Out:
# 0      (0.0757, 1.249]
# 1      (0.0757, 1.249]
# 2      (0.0757, 1.249]
# 3      (0.0757, 1.249]
# 4        (1.249, 2.42]
#             ...
# 763    (0.0757, 1.249]
# 764    (0.0757, 1.249]
# 765    (0.0757, 1.249]
# 766    (0.0757, 1.249]
# 767    (0.0757, 1.249]
# Name: DiabetesPedigreeFunction, Length: 768, dtype: category
# Categories (2, interval[float64]): [(0.0757, 1.249] < (1.249, 2.42]]

# %%
dataf=[data]

for dataset in dataf:
    dataset.loc[(dataset['DiabetesPedigreeFunction']>0.0757) &(dataset['DiabetesPedigreeFunction']<=1.249),'DiabetesPedigreeFunction' ]=0
    dataset.loc[(dataset['DiabetesPedigreeFunction']>1.249) &(dataset['DiabetesPedigreeFunction']<=2.42),'DiabetesPedigreeFunction' ]=1

dataset['DiabetesPedigreeFunction']=dataset['DiabetesPedigreeFunction'].astype(int)

# %%
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  BMI  \
# 0            2        1              2              1        0    1
# 1            0        0              2              1        0    1
# 2            2        1              2              0        0    1
# 3            0        0              2              1        0    1
# 4            0        1              1              1        0    1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                         0   50        1
# 1                         0   31        0
# 2                         0   32        1
# 3                         0   21        0
# 4                         1   33        1

# %%
ax = sns.lineplot(x="Age",y="Outcome",data=data)

# %%
pd.cut(data["Age"],5)
# Out:
# 0       (45.0, 57.0]
# 1      (20.94, 33.0]
# 2      (20.94, 33.0]
# 3      (20.94, 33.0]
# 4      (20.94, 33.0]
#            ...
# 763     (57.0, 69.0]
# 764    (20.94, 33.0]
# 765    (20.94, 33.0]
# 766     (45.0, 57.0]
# 767    (20.94, 33.0]
# Name: Age, Length: 768, dtype: category
# Categories (5, interval[float64]): [(20.94, 33.0] < (33.0, 45.0] < (45.0, 57.0] < (57.0, 69.0] < (69.0, 81.0]]

# %%
dataf = [data]

for dataset in dataf:
   
    dataset.loc[(dataset['Age'] > 20.94) & (dataset['Age'] <= 33.0), 'Age'] = 0
    dataset.loc[(dataset['Age'] > 33.0) & (dataset['Age'] <= 45.0), 'Age']   = 1
    dataset.loc[(dataset['Age'] > 45.0) & (dataset['Age'] <= 57.0), 'Age']   = 2
    dataset.loc[(dataset['Age'] > 57.0) & (dataset['Age'] <= 69.0), 'Age']   = 3
    dataset.loc[(dataset['Age'] > 69.0) & (dataset['Age'] <= 81.0), 'Age']   = 4
    
   
    dataset['Age'] = dataset['Age'].astype(int)

# %%
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  BMI  \
# 0            2        1              2              1        0    1
# 1            0        0              2              1        0    1
# 2            2        1              2              0        0    1
# 3            0        0              2              1        0    1
# 4            0        1              1              1        0    1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                         0    2        1
# 1                         0    0        0
# 2                         0    0        1
# 3                         0    0        0
# 4                         1    0        1

# %%
X=data.drop('Outcome',axis=1)
y=data['Outcome']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 12)

# %%
from sklearn import linear_model
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import Perceptron
from sklearn.linear_model import SGDClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC, LinearSVC
from sklearn.naive_bayes import GaussianNB

# %%
knn = KNeighborsClassifier(n_neighbors = 3)
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=3, p=2,
#                      weights='uniform')

# %%
y_pred = knn.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# %%
round(accuracy_score(y_test, y_pred)*100,2)
# Out:
# 69.27

# %%
lr = LogisticRegression()
lr.fit(X_train,y_train)
y_pred = lr.predict(X_test)
round(accuracy_score(y_test,y_pred)*100,2)
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# 71.35

# %%
rf = RandomForestClassifier(n_estimators=100)
rf.fit(X_train,y_train)
y_pred = rf.predict(X_test)
round(accuracy_score(y_test,y_pred)*100,2)
# Out:
# 67.19
